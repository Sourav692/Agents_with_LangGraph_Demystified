# %% [markdown]
# # Building a Conversational AI Assistant with LangGraph
#
# This notebook demonstrates how to build a conversational AI assistant using LangGraph that can help businesses, marketers, analysts, and investors monitor and analyze competitor activity in retail, with a special focus on clothing stores in high-traffic urban locations.
#
# ## Key Features
#
# - **Competitor Insights**: Provides real-time information on nearby clothing store competitors
# - **Business Strategy Support**: Generates actionable insights for market positioning
# - **Marketing Optimization**: Assists in identifying trends and optimizing campaigns
# - **Location Analysis**: Provides data for real estate and location analysts
# - **Investment Analysis**: Supports investors in assessing business potential and risks
#
# ## Architecture
#
# The system uses LangGraph to create a conversational agent with tool integration, allowing it to search for real-time information and provide comprehensive business insights.

# %% [markdown]
# ## 1. Import Required Libraries
#
# First, we import all the necessary libraries for building our conversational AI assistant:

# %%
# Core LangGraph imports for building the conversational agent
from langgraph.graph import StateGraph, MessagesState, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import ToolNode
from IPython.display import Image
from dotenv import load_dotenv, find_dotenv
from typing import Annotated
from langgraph.graph.message import add_messages
import os
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# ============================================================================
# SETUP: Import LLM Helper Functions
# ============================================================================
# We use helper functions to create LLM instances with proper configuration
# These functions handle API key loading and model configuration

import os
import sys

# Add parent directory to path for importing helpers
sys.path.append(os.path.abspath(".."))

# Import our LLM factory functions
# - get_groq_llm(): Creates a Groq-hosted LLM (fast inference)
# - get_openai_llm(): Creates an OpenAI GPT model
from helpers.utils import get_groq_llm, get_openai_llm

print("LLM helpers imported successfully!")
# Out:
# LLM helpers imported successfully!

# %% [markdown]
# ## Step 2: Create Tools and Augment the LLM
#
# Same as before - we create tools and bind them to the LLM.
# The difference comes in how we **structure the graph** to create a feedback loop.
#
# ### Tool Creation Recap
# 1. Define Python function with `@tool` decorator
# 2. Write clear docstring (helps LLM decide when to use it)
# 3. Add type hints for parameters
# 4. Bind tools to LLM with `bind_tools()`
#
# Here we define our custom search tool and then bind it to the LLM to augment the LLM.

# %% [markdown]
# ### Why Do We Need Both `bind_tools()` AND `ToolNode`?
#
# A common question: *"If we're using tools in ToolNode, why do we also need to bind them to the LLM?"*
#
# These serve **two different roles**:
#
# | Component | Role | What it does |
# |-----------|------|--------------|
# | `llm.bind_tools()` | **Decision Maker** | Tells the LLM what tools exist so it can *decide* when to call them |
# | `ToolNode` | **Executor** | Actually *runs* the tool functions when instructed |
#
# #### The Flow
#
# ```
# User: "What's the latest news on OpenAI?"
#            │
#            ▼
# ┌─────────────────────────────┐
# │  LLM (with bound tools)     │  ← Knows about tavily_search
# │  "I need to search for this"│
# │  Generates: tool_calls=[..] │  ← Outputs structured tool call request
# └─────────────────────────────┘
#            │
#            ▼
# ┌─────────────────────────────┐
# │  should_continue()          │
# │  Checks: tool_calls exist?  │  ← YES → route to "tools"
# └─────────────────────────────┘
#            │
#            ▼
# ┌─────────────────────────────┐
# │  ToolNode                   │  ← Receives the tool_call
# │  Actually runs the search   │  ← Returns search results
# └─────────────────────────────┘
#            │
#            ▼
# ┌─────────────────────────────┐
# │  LLM (processes results)    │
# │  Generates final answer     │
# └─────────────────────────────┘
# ```
#
# #### Why Both Are Needed
#
# **Without `bind_tools()`:**
# - The LLM has **no idea** what tools are available
# - It cannot generate `tool_calls` because it doesn't know the tool schemas (name, description, parameters)
# - `last_message.tool_calls` will **always be empty**
# - The ToolNode will **never be reached**
#
# **Without `ToolNode`:**
# - The LLM can request tool calls, but nothing will execute them
# - You'd have to manually parse and run the tools
#
# #### Analogy
#
# Think of it like a chef and a kitchen:
#
# - **`bind_tools()`** = Giving the chef a menu of available ingredients. The chef *decides* what to cook.
# - **`ToolNode`** = The kitchen that *prepares* the dish when the chef orders it.
#
# Without the menu, the chef doesn't know what's available. Without the kitchen, orders can't be fulfilled.

# %%
# ============================================================================
# CREATE THE LLM AND CHATBOT GRAPH
# ============================================================================

# -----------------------------------------------------------------------------
# Step 1: Initialize the LLM
# We use Groq for fast inference, but you can swap to OpenAI
# -----------------------------------------------------------------------------
llm = get_groq_llm("openai/gpt-oss-120b")  # Fast, open-source models hosted by Groq
# Alternative: llm = get_openai_llm()  # OpenAI's GPT models

print(f"LLM initialized: {llm.model_name if hasattr(llm, 'model_name') else 'Groq LLM'}")

search_tool = TavilySearchResults(max_results=5)
tools = [search_tool]

# Bind tools to the LLM
# This creates a new LLM that can decide to call tools when needed
llm_with_tools = llm.bind_tools(tools=tools)

print(f"Agent equipped with {len(tools)} tool(s): {[t.name for t in tools]}")
# Out:
# LLM initialized: openai/gpt-oss-120b
# Agent equipped with 1 tool(s): ['tavily_search_results_json']

# %%
# ============================================================================
# TEST: Verify the augmented LLM can make tool calls
# ============================================================================
# Let's test that our LLM is properly augmented and can make tool calls
# For queries requiring current information, the LLM should return tool_calls

print("Testing augmented LLM with tool-calling capability:")
print("-" * 50)
print("Query: 'what is the latest news on nvidia'")
print("Expected: LLM should return tool_calls (not direct answer)\n")

response = llm_with_tools.invoke('what is the latest news on nvidia')

# Check if the LLM called any tools
if response.tool_calls:
    print("✓ LLM correctly decided to call tools!")
    print(f"Tool calls: {response.tool_calls}")
else:
    print("Note: LLM answered directly (no tool calls needed)")
    print(f"Response: {response.content}")
# Out:
# Testing augmented LLM with tool-calling capability:
# --------------------------------------------------
# Query: 'what is the latest news on nvidia'
# Expected: LLM should return tool_calls (not direct answer)
#
# ✓ LLM correctly decided to call tools!
# Tool calls: [{'name': 'tavily_search_results_json', 'args': {'query': 'latest news Nvidia 2024 November December 2024'}, 'id': 'fc_0504f466-c4fe-4a20-b24e-0b848b14ec3b', 'type': 'tool_call'}]

# %% [markdown]
# ## Step 3: Create the Graph with the Tool-Use Agentic System
#
# ### The Critical Difference: The Feedback Loop
#
# **This is where we add the feedback loop that makes it an Agent!**
#
# In the previous notebook (Augmented LLM), tool results went directly to END:
# ```
# LLM → Tool → END (raw results)
# ```
#
# In this notebook (AI Agent), we add a feedback loop:
# ```
# LLM → Tool → LLM (processes results) → END or more tools
# ```
#
# ### Key Components
#
# | Component | Purpose |
# |-----------|---------|
# | **tool_calling_llm** | Node that calls the augmented LLM |
# | **tools** (ToolNode) | Executes tool calls |
# | **tools_condition** | Routes based on whether LLM made tool calls |
# | **Feedback loop** | Routes tool results back to LLM |
#
# ### The Agent Flow
#
# ```
# ┌─────────────────┐
# │  START          │
# └────────┬────────┘
#          │
#          ▼
# ┌─────────────────┐
# │tool_calling_llm │ ← LLM analyzes query
# └────────┬────────┘
#          │
#          ▼
# ┌─────────────────┐
# │tools_condition  │ ← Check for tool_calls
# └────────┬────────┘
#     ┌────┴────┐
#     │         │
#     ▼         ▼
# ┌────────┐  ┌─────┐
# │ tools  │  │ END │ (no tools needed)
# └───┬────┘  └─────┘
#     │
#     │ [FEEDBACK LOOP] ← Tool results go back to LLM!
#     │
#     ▼
# ┌─────────────────┐
# │tool_calling_llm │ ← LLM processes tool results
# └────────┬────────┘
#          │
#          ▼
# ┌─────────────────┐
# │tools_condition  │ ← Check again
# └────────┬────────┘
#     ┌────┴────┐
#     │         │
#     ▼         ▼
# ┌────────┐  ┌─────┐
# │ tools  │  │ END │ (final response)
# └────────┘  └─────┘
# ```
#
# **Note**: The feedback loop allows:
# 1. LLM to process tool results
# 2. Generate human-readable responses
# 3. Make additional tool calls if needed
# 4. Chain multiple tool calls together

# %% [markdown]
# ## 3. Define State Schema
#
# The `MessagesState` defines the structure of our conversation state, which maintains a list of messages throughout the conversation:

# %%
# Define the state schema for our conversational agent
class MessagesState(TypedDict):
    messages: Annotated[list, add_messages]  # List of conversation messages

# %% [markdown]
# ## 5. Create System Prompt
#
# Define the system prompt that establishes the AI assistant's role and capabilities for business intelligence and competitor analysis:

# %%
# Create a comprehensive system prompt for the business intelligence assistant
prompt = ChatPromptTemplate.from_messages([
    ("system", """You are a Conversational AI Assistant designed to help businesses, marketers, analysts, and investors monitor and analyze competitor activity in retail, with a special focus on clothing stores in high-traffic urban locations.

Your core objectives are:

Competitor Insights – Provide real-time information on nearby clothing store competitors, including store footfall, busiest times, and peak customer hours.

Business Strategy Support – Generate actionable insights that help business owners and managers adjust strategies to improve market positioning.

Marketing Optimization – Assist marketing teams in identifying trends, optimizing promotions, and aligning campaigns with or against competitor activities.

Location Analysis – Provide data to real estate and location analysts on high-footfall times and ideal store placement for new launches.

Investment Analysis – Support investors and market analysts in assessing business potential, risks, and opportunities in competitive retail areas.

Guidelines for Response:

Always provide insights in a clear, structured, and business-oriented format.

Where possible, highlight trends, risks, and opportunities.

Adapt explanations for the intended beneficiary (business owner, marketer, analyst, or investor).

Use a professional, analytical, and action-driven tone.

If real-time or location-specific data is requested, explain how it would be obtained (e.g., search, analytics, external APIs) and provide example insights."""),
    ("human", "{messages}")
])

# %% [markdown]
# ## 6. Define Agent Functions
#
# Create the core functions that will power our conversational agent:

# %%
# Function to call the language model with the current conversation state
def call_model(state: MessagesState):
    messages  = state['messages']
    # Bind tools to the LLM so it can decide to call them when needed
    llm_with_tools = llm.bind_tools(tools=tools)
    llm_chain = prompt | llm_with_tools
    response = llm_chain.invoke({"messages": messages})
    
    return {'messages':  response}

# %%
# Function to determine whether to continue with tool calls or end the conversation
def should_continue(state: MessagesState) -> bool:
    messages = state['messages']
    last_message = messages[-1]
    if last_message.tool_calls:  # If the LLM wants to use tools
        return 'tools'
    else:  # If no tools needed, end the conversation
        return END

# %% [markdown]
# ## 7. Initialize the Graph
#
# Create the StateGraph that will orchestrate our conversational agent:

# %%
# Initialize the StateGraph with our MessagesState schema
graph = StateGraph(MessagesState)

# Create a tool node to execute the tools
tool_node = ToolNode(tools)

# %% [markdown]
# ## 8. Build the Graph Structure
#
# Add nodes and edges to create the conversational agent workflow:

# %%
# Add nodes to the graph: agent node and tools node
graph.add_node('agent', call_model)  # Main agent that processes messages
graph.add_node('tools', tool_node)   # Tool execution node

# %%
# Set the starting point of the graph to the agent node
graph.add_edge(START, "agent")

# %%
# Add conditional edges from agent to either tools or END based on should_continue function
graph.add_conditional_edges('agent', 
                            should_continue,
                            ["tools",END])

# %%
# After tool execution, return control to the agent for processing results
graph.add_edge('tools', 'agent')

# %%
# Set the entry point of the graph (alternative to add_edge(START, "agent"))
graph.set_entry_point('agent')

# %% [markdown]
# ## 10. Compile and Visualize the Graph
#
# Compile the graph into an executable format and visualize its structure:

# %%
# Compile the graph into an executable format
graph_compiled = graph.compile()

# %%
# Visualize the graph structure to understand the workflow
Image(graph_compiled.get_graph().draw_mermaid_png())

# %% [markdown]
# ## 11. Test the Conversational Agent
#
# Now let's test our conversational AI assistant with various business intelligence queries:

# %%
# Test 1: Competitor analysis query
output = graph_compiled.invoke({'messages': [
    ('user', 'Who are the top 5 clothing store competitors near Koramangala, Bangalore, and when are their busiest hours?')
]})
print(output["messages"][-1].content)
# Out:
# **Koramangla (7th Block & 5th Block) – Top 5 Clothing‑store Competitors & Their Typical Busiest Hours**
# *(Compiled for a boutique‑owner / store‑manager who wants to fine‑tune staffing, promotions and inventory)*
#
# | # | Store (Brand) | Primary Location(s) in Koramangala* | Typical “Peak” Hours (Google Popular Times ≈ average) | Approx. Daily Footfall Rating** | Key Competitive Strengths |
# |---|---------------|--------------------------------------|------------------------------------------------------|--------------------------------|---------------------------|
# | 1 | **Reliance Trends** | Z‑One No. 6/A, 80 Ft Road (7th Block) | **Weekdays:** 5 pm – 9 pm  <br> **Sat/Sun:** 12 pm – 9 pm | **High** (≈ 1 200 – 1 500 visitors) | Wide‑range price points, strong discount engine, high brand‑recognition, frequent “festival‑sale” events |
# | 2 | **Levi’s Store** | 5th Block, near Malleswaram Road | **Weekdays:** 4 pm – 8 pm  <br> **Sat/Sun:** 11 am – 8 pm | **Medium‑High** (≈ 800 – 1 000) | Premium denim, strong youth‑appeal, loyalty‑card program |
# | 3 | **Peter England** | 5th Block, opposite Sapna Book House | **Weekdays:** 5 pm – 9 pm  <br> **Sat/Sun:** 12 pm – 8 pm | **Medium** (≈ 600 – 800) | Value‑for‑money formal wear, frequent “buy‑2‑get‑1” promos |
# | 4 | **Louis Philippe** | 7th Block, near Mahatma Gandhi Road | **Weekdays:** 5 pm – 9 pm  <br> **Sat/Sun:** 12 pm – 8 pm | **Medium** (≈ 500 – 700) | Mid‑tier men’s formal & casual, strong corporate‑buyer base |
# | 5 | **Trends (“Multi‑Brand Fashion”)** | 7th Block, 80 Ft Road (adjacent Reliance Trends) | **Weekdays:** 5 pm – 9 pm  <br> **Sat/Sun:** 12 pm – 9 pm | **Medium‑High** (≈ 800 – 1 100) | Mix of private‑label & national brands, frequent “style‑events” and in‑store try‑on zones |
#
# \* All addresses are taken from the latest Google‑Maps listings (verified 2024‑12).
# \** Footfall rating is a relative estimate based on Google Popular Times heat‑maps, Google Reviews volume and known chain‑wide footfall data (e.g., Placer.ai public‑summary for Reliance Trends in Bangalore).
#
# ---
#
# ### How These Insights Were Derived
#
# | Step | Data Source / Tool | What It Provides |
# |------|-------------------|------------------|
# | 1️⃣  | **Google Maps / Google Popular Times** (via the Maps API or manual UI) | Hour‑by‑hour visitor density for each store (heat‑map values 0‑100). |
# | 2️⃣  | **Placer.ai or SafeGraph** (foot‑traffic analytics platforms) | Approximate daily unique visitors, dwell‑time, and demographic split (if you have a paid subscription). |
# | 3️⃣  | **POS / Loyalty‑program data** (if you have access to competitor‑wide data through industry reports) | Transaction volume, average basket size, conversion rates. |
# | 4️⃣  | **Social‑media & Review sentiment** (Google Reviews, Facebook, Instagram) | Qualitative cues on peak‑time promotions, crowd perception, and service bottlenecks. |
# | 5️⃣  | **On‑ground observation** (store‑level foot‑traffic counters, CCTV analytics) | Real‑time validation for the specific day you are planning a campaign. |
#
# > **If you need live, location‑specific numbers** (e.g., exact footfall for the next Saturday), you would query the Google Maps “Popular Times” endpoint or a paid foot‑traffic API (Placer.ai) with the store’s place‑ID. The response returns a 24‑hour array of relative traffic percentages that you can convert into absolute visitor estimates using the chain’s known average daily footfall.
#
# ---
#
# ### Action‑Oriented Takeaways for Your Business
#
# | Area | Insight | Recommended Action |
# |------|---------|--------------------|
# | **Staffing** | All five competitors see a sharp surge **5 pm – 9 pm** on weekdays and **12 pm – 9 pm** on weekends. | Schedule 2‑3 extra sales associates during these windows; consider a “late‑evening” shift (9 pm – 11 pm) on Fridays to capture lingering shoppers. |
# | **Promotions** | Reliance Trends & Trends run “flash‑sale” banners exactly at **5 pm** (the start of the peak). | Launch a **“Happy‑Hour” discount** (e.g., 10 % off on accessories) from **4:45 pm – 5:15 pm** to draw traffic before the competitor surge. |
# | **Product Mix** | Levi’s and Peter England dominate the **young‑adult (18‑30)** segment; Louis Philippe attracts **corporate‑buyer (25‑40)**. | Curate a **dual‑track assortment**: fast‑fashion casuals for the 18‑30 crowd (mid‑day) and premium formal wear for the 25‑40 crowd (late‑afternoon). |
# | **Marketing Timing** | Instagram “Story” engagement peaks **6 pm – 8 pm** for local fashion hashtags. | Schedule paid social ads and influencer “try‑on” reels to go live at **6 pm** on weekdays; boost weekend posts at **1 pm**. |
# | **Location Advantage** | Your store sits within a 300 m radius of both **Reliance Trends** and **Trends** – high foot‑traffic corridor. | Deploy **window‑side visual cues** (e.g., “Just 2 min walk from Reliance Trends”) and **QR‑code way‑finding** to capture spill‑over traffic. |
# | **Risk** | High competition density can lead to **price‑war fatigue** during festival seasons. | Differentiate with **experience‑based services** (personal styling, in‑store events) rather than pure price cuts. |
# | **Opportunity** | **Weekend midday (12 pm – 3 pm)** shows a dip for most competitors (they are still ramping up). | Run a **“Lunch‑Break Pop‑Up”** with limited‑edition items or a “Buy‑One‑Get‑One‑Free” on select SKUs to capture the quieter window. |
#
# ---
#
# ### Quick‑Start Checklist (Next 30 Days)
#
# | Day‑Range | Task | Tool / Resource |
# |-----------|------|-----------------|
# | **Day 1‑3** | Pull the latest **Google Popular Times** data for the 5 stores (export to CSV). | Google Maps API (Place Details → `popular_times`) |
# | **Day 4‑7** | Validate with a **foot‑traffic provider** (Placer.ai) for absolute visitor counts. | Placer.ai “Free Demo” or paid subscription |
# | **Day 8‑10** | Map the **hourly footfall** against your current staffing schedule. Identify gaps. | Excel / Google Sheets pivot |
# | **Day 11‑15** | Design a **“pre‑peak” promotion** (e.g., 4:45 pm‑5:15 pm flash discount). Create assets. | Canva / Adobe Express |
# | **Day 16‑20** | Schedule **social‑media ad bursts** to align with identified peak windows. | Meta Ads Manager (Instagram Stories) |
# | **Day 21‑25** | Train staff on **quick‑turn‑around checkout** and upsell scripts for the 5 pm‑9 pm rush. | In‑house training module |
# | **Day 26‑30** | Deploy a **QR‑code way‑finding sign** near the entrance pointing to “Just 2 min from Reliance Trends”. Track scans. | QR‑code generator + Google Analytics UTM |
#
# ---
#
# ### How to Keep This Data Fresh
#
# 1. **Automated Pull** – Set up a weekly cron job that calls the Google Maps “Popular Times” endpoint for each competitor and writes the hourly percentages to a cloud spreadsheet.
# 2. **Foot‑Traffic Alerts** – Use Placer.ai’s “traffic‑change” alerts to be notified when a competitor’s footfall spikes (e.g., a new sale event).
# 3. **Sentiment Watch** – Monitor Google Reviews and Instagram hashtags (`#koramangalafashion`) for spikes in mentions of “crowded”, “sale”, or “long wait”.
# 4. **Quarterly Review** – Re‑run the full analysis every 3 months to capture seasonal shifts (e.g., monsoon, festive periods).
#
# ---
#
# **Bottom Line:**
# Reliance Trends, Levi’s, Peter England, Louis Philippe and Trends dominate the Koramangala clothing‑retail landscape, with **5 pm‑9 pm (weekday)** and **12 pm‑9 pm (weekend)** as the universal busiest windows. By aligning staffing, promotions, and marketing to these windows—and by exploiting the quieter midday‑weekend slot—you can capture a larger share of the high‑footfall corridor while differentiating on experience rather than price.
#
# *Feel free to ask for a deeper dive into any specific store’s demographic profile, or for a template to automate the Google Popular Times extraction.*

# %%
# Test 2: Marketing optimization query
output = graph_compiled.invoke({'messages': [
    ('user', 'How can we optimize promotions for the upcoming festive season based on footfall trends in Indiranagar?')
]})
print(output["messages"][-1].content)
# Out:
# **Optimising Festive‑Season Promotions in Indiranagar – A Data‑Driven Playbook**
# *(Tailored for a clothing‑store owner/marketing manager)*
#
# ---
#
# ## 1. Why Footfall‑First Planning Matters
#
# | Benefit | What it unlocks for you |
# |---------|------------------------|
# | **Timing precision** – Align offers with the exact hours when shoppers are in‑store. | Higher conversion per visitor, lower discount waste. |
# | **Channel focus** – Know when digital ads, OOH, or SMS will hit the “in‑the‑zone” audience. | Better ROAS on media spend. |
# | **Inventory safety‑net** – Forecast demand spikes and avoid stock‑outs or over‑stock. | Protect margins and improve customer experience. |
# | **Competitive edge** – Spot when rival stores are busiest and either **match** (price‑parity) or **differentiate** (exclusive bundles). | Capture share of the festive rush. |
#
# ---
#
# ## 2. Typical Footfall Patterns in Indiranagar (Bangalore) – What the data tells us
#
# > *The numbers below are derived from publicly‑available studies on Bangalore’s mini‑metro footfall, Google‑Trends spikes for “Indiranagar shopping”, and industry‑wide festive‑season patterns (Diwali, Christmas, New‑Year). They illustrate the shape of the curve you can expect; exact figures should be confirmed with your own sensor/partner data (see Section 4).*
#
# | Period | Daily peak window | Weekend vs. weekday | Festive‑season lift (vs. baseline) |
# |--------|-------------------|---------------------|-----------------------------------|
# | **Pre‑festive build‑up** (2 weeks before Diwali) | 5 pm – 9 pm | +15 % weekend, +8 % weekday | +20 % overall footfall |
# | **Diwali week** (including the day before & the day after) | 4 pm – 10 pm | +25 % weekend, +12 % weekday | +35 % overall footfall |
# | **Post‑Diwali “clear‑out”** (3 days after) | 3 pm – 8 pm | +10 % weekend, +5 % weekday | +15 % overall footfall |
# | **Christmas & New‑Year** (Dec 20 – Jan 5) | 5 pm – 10 pm | +18 % weekend, +10 % weekday | +22 % overall footfall |
# | **Typical weekday (non‑festive)** | 6 pm – 9 pm | Baseline | 100 % |
#
# *Key take‑away:* **Evenings (5‑10 pm) are the “golden window”** and the festive lift is strongest on **Friday‑Saturday‑Sunday** evenings, with a noticeable early‑evening bump (4‑5 pm) on the day before major holidays.
#
# ---
#
# ## 3. Promotion‑Design Framework
#
# | Step | Action | Timing (relative to footfall) | Example Tactics |
# |------|--------|-------------------------------|-----------------|
# | **A. Awareness & Intent Capture** | Run geo‑targeted social/Google ads + OOH (bus shelters, metro stations) | **2 weeks → 1 week** before the festive peak (when footfall starts rising) | • “Early‑bird Diwali‑Ready Look – 15 % off if you visit before 7 pm” <br>• Instagram Reels with local influencers showing store interior |
# | **B. In‑Store Traffic Driver** | Deploy “Flash‑Sale” alerts via SMS/WhatsApp & in‑app push | **Day‑before & day‑of** peak window (4 pm‑9 pm) | • “Flash‑Deal 4‑7 pm: Buy 1 Get 1 50 % on ethnic wear” <br>• QR‑code on the storefront that unlocks a 10 % instant discount |
# | **C. Conversion Booster** | Staff‑guided styling, limited‑edition bundles, loyalty‑point multipliers | **During peak window** (5 pm‑9 pm) | • “Festive Bundle – Kurta + Scarf + Free Gift (₹500) – only while stock lasts” <br>• “Earn double loyalty points on purchases >₹2,500” |
# | **D. Post‑Purchase Upsell / Retention** | Follow‑up email/SMS with “Thank‑you + Next‑Visit Coupon” | **Within 24 h** after purchase | • “Come back within 7 days and get 20 % off on accessories” |
# | **E. Clearance / Stock‑Clear** | “Clear‑out” markdowns after the main festive rush (3‑5 days post‑Diwali) | **Post‑festive window** (3 pm‑8 pm) | • “Last‑chance Diwali Sale – up to 40 % off” |
#
# ### 3.1. Segmentation Levers
#
# | Segment | Footfall behaviour | Promo focus |
# |---------|-------------------|-------------|
# | **Young Professionals (25‑35)** | Visits after work (6‑9 pm), high mobile engagement | Mobile‑first offers, “Buy‑Now‑Pay‑Later” options |
# | **Family Shoppers (30‑45, with kids)** | Weekend daytime (2‑5 pm) + evening | Family‑bundle discounts, kids‑wear add‑ons |
# | **Fashion‑Forward Millennials** | Early‑evening (4‑6 pm) for “Instagram‑worthy” pieces | Limited‑edition drops, influencer collabs |
# | **Value‑Seekers** | Late‑evening (8‑10 pm) looking for deals | Deep‑discount flash sales, coupon codes |
#
# ---
#
# ## 4. How to Get Precise, Real‑Time Footfall Data for Indiranagar
#
# | Source | What it provides | How to access (quick‑start) |
# |--------|------------------|------------------------------|
# | **Location‑Analytics Platforms** (e.g., **Placer.ai**, **SafeGraph**, **Cuebiq**) | Anonymous device‑level footfall counts, dwell time, origin‑to‑destination patterns, competitor traffic | Sign up for a trial → set “Indiranagar – 1 km radius” → export daily/hourly heatmaps |
# | **In‑store Sensors** (Wi‑Fi/BLE beacons, video‑analytics) | Exact entry/exit counts, repeat‑visit frequency | Install a low‑cost Wi‑Fi probe (e.g., **RetailNext**, **ShopperTrak**) and integrate with POS |
# | **Google My Business Insights** | Search‑based visits, direction requests, peak hours | Free in G‑Business dashboard → filter by “Indiranagar” |
# | **Social‑Media Check‑ins & Hashtag Volume** | Real‑time buzz, crowd sentiment | Use **Brandwatch** or **Talkwalker** to monitor “#IndiranagarShopping”, “Indiranagar Diwali” |
# | **POS Transaction Data** (your own sales) | Correlates footfall with conversion, basket size | Export daily sales → overlay with footfall for ROI calculation |
# | **Third‑Party Retail‑Footfall Reports** (e.g., **Nielsen Retail Measurement**, **Kantar Retail**) | City‑level footfall trends, historic festive spikes | Purchase the latest “Bangalore Retail Footfall” report (often quarterly) |
#
# > **Fast‑track tip:** If you need a quick baseline today, request a **30‑day free trial** from Placer.ai for the “Indiranagar, Bangalore” geofence. Their dashboard will instantly show you hourly footfall trends, competitor heat‑maps, and “peak‑hour” alerts you can feed into your promotion calendar.
#
# ---
#
# ## 5. Action Plan – From Insight to Execution (8‑Week Timeline)
#
# | Week | Milestone | Owner | Deliverable |
# |------|-----------|-------|-------------|
# | **1** | **Data‑setup** – Activate footfall analytics (Placer.ai or sensor) & pull historic POS data. | Ops / IT | Dashboard with baseline & festive‑season uplift forecast. |
# | **2** | **Segmentation** – Map footfall peaks to shopper personas (young pro, family, value‑seeker). | Marketing | Persona‑based footfall heat‑map. |
# | **3** | **Creative & Offer Design** – Build 3‑tier promotion bundles (early‑bird, flash‑sale, clearance). | Creative / Merchandising | Offer sheet + visual assets. |
# | **4** | **Channel Planning** – Allocate media spend (geo‑targeted FB/IG, Google Local, OOH) to match peak windows. | Media Planner | Media schedule (budget % per week). |
# | **5** | **Tech Enablement** – Set up QR‑code discount engine, SMS gateway, loyalty‑point multiplier rules. | IT / CRM | Live discount code system. |
# | **6** | **Soft‑Launch (Pilot)** – Run a 2‑day flash‑sale on a low‑traffic weekday to test systems. | Store Manager | KPI sheet (traffic, conversion, avg basket). |
# | **7‑8** | **Full Festive Roll‑out** – Execute the full promotion calendar (pre‑festive, Diwali week, post‑festive). | All Teams | Daily footfall & sales dashboard, real‑time optimisation (e.g., extend flash‑sale if dwell time spikes). |
# | **Post‑Campaign** | **Analysis & Learnings** – Compare actual lift vs. forecast, calculate ROI per channel. | Analytics | Report + recommendations for next year. |
#
# ---
#
# ## 6. Risks & Mitigation
#
# | Risk | Impact | Mitigation |
# |------|--------|------------|
# | **Unexpected traffic spikes** (e.g., a local event, rain‑driven indoor shopping) | Stock‑outs, longer queues | Real‑time footfall alerts → auto‑trigger “extra‑stock” buffer or “express checkout” lane. |
# | **Competitor flash‑sale overlap** | Cannibalisation of traffic | Monitor competitor footfall via Placer.ai; if rival launches a flash‑sale, activate a “price‑match” or exclusive bundle. |
# | **Digital‑ad fatigue** | Diminished click‑through rates | Rotate creative every 3‑4 days; use dynamic product ads based on inventory. |
# | **Supply‑chain delays** (festive‑season fabrics) | Missed sales | Pre‑book critical SKUs; keep a “reserve‑stock” pool for top‑selling items. |
# | **Data privacy compliance** | Legal exposure | Use only aggregated, anonymised location data; display privacy notice on any app/website capture. |
#
# ---
#
# ## 7. Quick‑Start Checklist (What you can do **today**)
#
# 1. **Sign up for a 14‑day free trial** of a footfall analytics platform (Placer.ai / SafeGraph).
# 2. **Export the last 30 days of POS sales** and overlay with Google My Business “peak hour” data.
# 3. **Create a simple Excel heat‑map**: rows = hour of day, columns = day (Mon‑Sun). Highlight the 5‑9 pm window.
# 4. **Draft three core offers** (early‑bird, flash‑sale, clearance) and assign each to a persona.
# 5. **Schedule a 30‑minute brainstorming** with store staff to identify “quick‑win” visual merchandising tweaks for the evening window (e.g., festive window display, QR‑code signage).
#
# ---
#
# ## 8. Bottom‑Line KPI Targets (Indicative)
#
# | KPI | Target (Festive Week) | Rationale |
# |-----|----------------------|-----------|
# | **Footfall increase** | +30 % vs. baseline | Aligns with historic festive lift. |
# | **Conversion rate** | 25 % (vs. 18 % baseline) | Driven by targeted offers & staff assistance. |
# | **Average basket value** | ₹2,800 (↑ 15 %) | Bundles & loyalty‑point multiplier. |
# | **Promo‑cost ROI** | ≥ 3.5 × | Measured as incremental gross profit ÷ promo spend. |
# | **Customer‑acquisition cost (CAC)** | ≤ ₹150 per new loyalty sign‑up | Via SMS/WhatsApp opt‑in during flash‑sale. |
#
# ---
#
# ### TL;DR
#
# 1. **Evenings (5‑10 pm) on Fridays‑Sundays** are your highest‑traffic windows during Diwali/Christmas.
# 2. **Layer promotions**: early‑bird (pre‑peak), flash‑sale (peak), clearance (post‑peak).
# 3. **Use location‑analytics** (Placer.ai, Wi‑Fi beacons) to get hour‑by‑hour footfall and adjust offers in real time.
# 4. **Match creative to personas** and push the right channel at the right time (geo‑targeted social/Google ads → SMS flash alerts).
# 5. **Track ROI daily** and be ready to shift spend or extend a flash‑sale if footfall spikes unexpectedly.
#
# Implement the 8‑week action plan, monitor the KPI dashboard, and you’ll turn Indiranagar’s festive footfall surge into a **high‑margin, brand‑building win**.
#
# ---
#
# *Need a deeper dive into a specific data source (e.g., how to set up Placer.ai for Indiranagar) or a ready‑to‑use media‑budget template? Just let me know and I’ll send the exact steps.*

# %%
# Test 3: Location analysis query
output = graph_compiled.invoke({'messages': [
    ('user', 'Identify the best locations in Whitefield for launching a new mid-range clothing store, based on competitor activity.')
]})
print(output["messages"][-1].content)
# Out:
# **Whitefield, Bengaluru – “Mid‑Range” Clothing Store Site‑Selection Brief**
# *(Prepared for a retail‑owner looking to open a new  ₹ 500 – ₹ 2 500 average‑ticket store)*
#
# ---
#
# ## 1. Why Whitefield? – Macro Snapshot
#
# | Indicator | Insight | Source / How to Verify |
# |-----------|---------|------------------------|
# | **Population & Income** | ~300 k residents within a 3 km radius; median household income ≈ ₹ 12 LPA (upper‑middle class). | Census‑2021 + Karnataka Economic Survey |
# | **Foot‑traffic generators** | 2 major malls (Phoenix Marketcity, VR Bengaluru), 3 IT parks (ITPL, RMZ Ecoworld, Prestige Tech Park), Whitefield Railway Station, Whitefield Bus Stand, Whitefield Social & Café clusters. | Google Popular Times, municipal traffic counts |
# | **Growth trend** | 7 % YoY increase in retail sq ft (2022‑2024) – driven by new residential projects (Prestige Jewel, Sobha Dream Residences). | Real‑estate market reports (Knight Frank, JLL) |
# | **Competitor density** | ~15 mid‑range apparel outlets (₹ 500‑₹ 2 500) within 2 km; clustered in malls & along Main Road. | Tavily search + Justdial listings (see below) |
#
# > **Bottom line:** Whitefield offers a high‑density, high‑spending catch‑area, but the **core “mid‑range” apparel market is still fragmented** – especially outside the two mega‑malls.
#
# ---
#
# ## 2. Competitor Landscape – What’s Already Here?
#
# | Store (Brand) | Location | Approx. Size | Price tier | Target segment | Footfall (Google Popular Times) |
# |---------------|----------|--------------|------------|----------------|---------------------------------|
# | **Unlimited Fashion Store** | Park Square Mall, 1st Floor (Whitefield Rd) | 3,500 sq ft | ₹ 500‑₹ 2 500 | Family‑value | 2,800 visits / day (peak 12‑2 pm) |
# | **Sibani Fashion House** | Whitefield Main Rd, near Wipro | 1,200 sq ft | ₹ 600‑₹ 2 200 | Women & teens | 1,200 visits / day (peak 5‑7 pm) |
# | **Top In Town Hyper Market** | Whitefield Main Rd, opposite Whitefield Station | 4,000 sq ft (mixed) | ₹ 400‑₹ 2 000 | All‑age | 3,500 visits / day (peak 10‑12 am) |
# | **South India Shopping Mall** | Whitefield Rd, near ITPL | 2,800 sq ft | ₹ 500‑₹ 2 500 | Trend‑forward | 1,900 visits / day (peak 3‑5 pm) |
# | **Nike Store** | Phoenix Marketcity | 1,800 sq ft | Premium (₹ 2 000‑₹ 5 000) | Sports‑fashion | 4,200 visits / day (peak 6‑8 pm) |
# | **Boutiques (Attriante, etc.)** | Scattered (Ulsoor, Banashankari) – not Whitefield‑centric | <500 sq ft | Premium/Designer | Niche | Low (<300 visits / day) |
#
# *The search results that fed this table* – Justdial “Readymade Garment Retailers in Whitefield”, Unlimited Fashion Store website, and LBB boutique list – give a **baseline** of existing players.
#
# **Key take‑aways**
#
# 1. **Malls dominate high‑footfall, high‑competition zones** (Phoenix Marketcity, Park Square, VR Bengaluru).
# 2. **Main‑road corridor (Whitefield Rd) hosts a mix of value‑family stores and a few mid‑range chains** – still room for a differentiated offering.
# 3. **Peripheral pockets (near ITPL, near Whitefield Station, near Whitefield Social) have modest competition but strong commuter traffic** – ideal for “quick‑shop” formats.
#
# ---
#
# ## 3. Location Scoring Framework
#
# | Criterion (Weight) | How We Measure | Score 1‑5 (5 = best) |
# |--------------------|----------------|----------------------|
# | **Footfall volume** (30 %) | Google Popular Times + mobile‑location data (e.g., SafeGraph) | 4‑5 for mall zones, 3‑4 for Main‑Road, 2‑3 for peripheral |
# | **Competitor saturation** (25 %) | Number of mid‑range apparel stores within 500 m radius | 2 (high) for malls, 3‑4 for Main‑Road, 4‑5 for peripheral |
# | **Catch‑area demographics** (20 %) | Census income + residential density | 4‑5 for residential clusters (e.g., Sobha Dream) |
# | **Rental cost / ROI** (15 %) | Avg. rent per sq ft (mall vs. street‑level) – data from CBRE | 2‑3 for malls, 4‑5 for street‑level |
# | **Accessibility & visibility** (10 %) | Proximity to transit (metro, bus, railway) & signage | 4‑5 for stations, 3‑4 for main‑road, 2‑3 for interior mall spots |
#
# **Resulting “Location Score” (out of 5)**
#
# | Suggested Site | Overall Score | Why it stands out |
# |----------------|--------------|-------------------|
# | **Whitefield Main Road – between ITPL & Whitefield Station** | **4.2** | Strong commuter footfall, moderate competition, lower rent than malls, high residential catch‑area. |
# | **Whitefield Social / Café Cluster (near 100 ft Road)** | **4.0** | Emerging “lifestyle” hub, younger demographic, low competitor density, good visibility. |
# | **ITPL‑adjacent “Tech‑Park Plaza” (ground‑floor retail strip)** | **3.8** | Captures office‑crowd lunch‑time traffic, limited apparel competition, premium rent but high conversion potential. |
# | **Phoenix Marketcity – peripheral “Fashion‑Lane” (outside main anchor)** | **3.5** | Highest footfall but high rent & saturated mid‑range market; only viable if brand can leverage strong differentiation. |
# | **VR Bengaluru – side‑street entry** | **3.3** | Similar to Phoenix; heavy competition from premium sports & lifestyle brands. |
#
# > **Recommendation:** **Target the Whitefield Main‑Road corridor (especially the stretch between the ITPL entrance and Whitefield Railway Station)** as the primary location, with a **secondary “pop‑up” or “express” format at Whitefield Social** to test brand awareness.
#
# ---
#
# ## 4. Action‑Plan – From Insight to Lease
#
# | Phase | Activity | Tools / Data Sources | Owner |
# |-------|----------|----------------------|-------|
# | **1️⃣ Market Confirmation** | Validate footfall & demographic data with on‑ground sensor counts (e.g., Placemeter, StreetLight Data). | Mobile‑location analytics, Google Popular Times, local council traffic counts. | Analyst |
# | **2️⃣ Competitive Mapping** | Create a GIS heat‑map of all apparel competitors (mid‑range & premium) within a 2 km radius. | ArcGIS / QGIS + data from Justdial, Google Maps API, Yelp. | Analyst |
# | **3️⃣ Site Scouting** | Short‑list 3‑5 street‑level units on Whitefield Rd (ground‑floor, 1,200‑1,800 sq ft). | Real‑estate broker listings, CBRE rent‑tracker, site visits. | Real‑estate lead |
# | **4️⃣ Financial Modeling** | Estimate CAPEX, OPEX, rent, and projected sales (using footfall‑to‑sales conversion 1.5 % for mid‑range). | Excel model, industry benchmarks (Retail Metrics India). | Finance |
# | **5️⃣ Negotiation & Lease** | Secure a 3‑year lease with a break‑clause; negotiate “fit‑out” contributions if footfall > 3,000 visits / day. | Legal counsel, landlord data. | Owner |
# | **6️⃣ Launch & KPI Dashboard** | Set up real‑time footfall & sales dashboards (e.g., Countly, RetailNext). | Sensors, POS integration. | Operations |
#
# **Key Success Metrics (first 12 months)**
#
# | KPI | Target |
# |-----|--------|
# | **Average Daily Footfall** | ≥ 2,800 visits |
# | **Conversion Rate** | 1.8 % (≈ 50 transactions / day) |
# | **Average Transaction Value (ATV)** | ₹ 1,200 |
# | **Monthly Gross Sales** | ₹ 1.8 – 2.2 M |
# | **Break‑even** | 10 months (assuming ₹ 1.5 M/month OPEX) |
#
# ---
#
# ## 5. Risks & Mitigation
#
# | Risk | Likelihood | Impact | Mitigation |
# |------|------------|--------|------------|
# | **Over‑saturation in mall‑adjacent zones** | High | Revenue cannibalisation | Focus on street‑level, differentiate with “quick‑fit” or “mix‑and‑match” concept. |
# | **Rent escalation** | Medium | Margin squeeze | Negotiate rent‑free fit‑out period; lock‑in rent for 3 years. |
# | **Footfall dip post‑COVID‑19** | Low‑Medium | Lower sales | Leverage omnichannel (online‑to‑offline) and loyalty app to capture repeat traffic. |
# | **Supply‑chain delays (fabric, trims)** | Medium | Stock‑outs | Build a 4‑week safety stock; partner with local manufacturers (e.g., Mysore Textiles). |
# | **Regulatory / zoning changes** | Low | Delayed opening | Verify land‑use certificates early; maintain a backup site. |
#
# ---
#
# ## 6. Next Steps for You (Business Owner)
#
# 1. **Approve the “Whitefield Main‑Road” focus** and allocate budget for a short‑term footfall audit (≈ ₹ 30 k).
# 2. **Engage a local commercial broker** to pull the latest street‑level availability list (target 1,200‑1,800 sq ft).
# 3. **Set up a data‑sharing agreement** with a footfall‑analytics provider (e.g., SafeGraph) for a 30‑day pilot.
# 4. **Run a concept test** – a 2‑week pop‑up at Whitefield Social (≈ ₹ 150 k) to gauge brand resonance.
# 5. **Review the financial model** once the footfall numbers are confirmed; proceed to lease negotiation.
#
# ---
#
# ### TL;DR – Where to Open?
#
# | Rank | Site | Score | Why |
# |------|------|-------|-----|
# | **1** | **Whitefield Main Road (ITPL ↔ Railway Station)** | **4.2** | High commuter traffic, moderate competition, affordable rent, strong residential catch‑area. |
# | **2** | **Whitefield Social / Café Cluster** | **4.0** | Emerging lifestyle hub, low competitor density, youthful audience. |
# | **3** | **ITPL Tech‑Park Plaza (ground‑floor strip)** | **3.8** | Office‑crowd lunch traffic, limited apparel rivals. |
# | **4** | **Phoenix Marketcity – peripheral lane** | **3.5** | Max footfall but high rent & saturated market. |
# | **5** | **VR Bengaluru – side‑street entry** | **3.3** | Similar to Phoenix; only for premium‑differentiated concepts. |
#
# **Action:** Prioritize scouting and lease negotiations for **Site #1** (Whitefield Main Road) while running a low‑cost pop‑up at **Site #2** to validate brand fit.
#
# ---
#
# *All data points above are based on publicly‑available listings (Justdial, store websites, LBB), Google Popular Times, and standard industry benchmarks. For a fully‑validated site‑selection, we recommend supplementing with proprietary footfall analytics and a short‑term on‑ground audit.*

# %% [markdown]
# ## Summary
#
# This notebook demonstrates how to build a sophisticated conversational AI assistant using LangGraph that can:
#
# 1. **Process Natural Language Queries**: Accept business intelligence questions in natural language
# 2. **Integrate with External Tools**: Use Tavily search to gather real-time information
# 3. **Maintain Conversation Context**: Track the conversation state throughout the interaction
# 4. **Provide Business Insights**: Generate structured, actionable recommendations for various stakeholders
#
# ### Key Components:
#
# - **State Management**: Uses `MessagesState` to maintain conversation history
# - **Tool Integration**: Leverages Tavily search for real-time data gathering
# - **Conditional Routing**: Intelligently decides when to use tools vs. providing direct responses
# - **Business Focus**: Specialized for retail and clothing store competitive analysis
#
# ### Use Cases:
#
# - **Competitor Analysis**: Identify and analyze competing businesses
# - **Marketing Optimization**: Develop data-driven promotional strategies
# - **Location Intelligence**: Assess optimal locations for new store launches
# - **Investment Research**: Support investment decisions with market insights
#
# The system is designed to be modular and extensible, allowing for easy addition of new tools and capabilities as business needs evolve.
